# %%
from simworld.communicator.communicator import Communicator
from simworld.communicator.unrealcv import UnrealCV

# %%
communicator = Communicator(UnrealCV(port=9000, ip='18.237.162.82'))

# %%
image = communicator.unrealcv.get_image(0, 'lit')

print(image)
