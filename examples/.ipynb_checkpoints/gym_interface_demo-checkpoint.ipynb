# %% [markdown]
# ## Import libraries

# %%
import sys
import threading
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from simworld.config import Config
from simworld.communicator.communicator import Communicator
from simworld.communicator.unrealcv import UnrealCV
from simworld.traffic.controller.traffic_controller import TrafficController
from simworld.traffic.base.traffic_signal import TrafficSignalState
from simworld.llm.a2a_llm import A2ALLM
from simworld.llm.base_llm import BaseLLM
from simworld.map.map import Map
from simworld.agent.humanoid import Humanoid
from simworld.utils.vector import Vector
from simworld.local_planner.local_planner import LocalPlanner

# %% [markdown]
# ## Init

# %%
communicator = Communicator(UnrealCV())
# Out:
# INFO:__init__:230:Got connection confirm: b'connected to gym_citynav'
# =>Info: using ip-port socket

# %%
import os
os.environ['OPENAI_API_KEY'] = 'removed'  # Replace with your actual OpenAI API key'

# %% [markdown]
# ## Agent

# %%
class Agent():
    def __init__(self, goal):
        self.goal = goal
        self.llm = BaseLLM("gpt-4o")
        self.system_prompt = f"You are an intelligent agent in a 3D world. Your goal is to: {self.goal}."

    def action(self, obs):
        prompt = f"{self.system_prompt}\n You are currently at: {obs}\nWhat is your next goal?"
        action = self.llm.generate_text(system_prompt=self.system_prompt, user_prompt=prompt)
        return action

# %%
class Environment:
    def __init__(self, communicator, config=Config()):
        self.communicator = communicator
        self.agent = None
        self.target = None
        self.action_planner = None
        self.config = config
        self.action_planner_llm = A2ALLM(model_name="gpt-4o-mini")
        self.map = Map(config)
        self.map.initialize_map_from_file(roads_file= os.path.join('../simworld/roads.json')) # use default map

    def reset(self):
        """Clear the UE scene and (re)spawn the humanoid and target."""
        # Clear spawned objects
        self.communicator.clear_env()

        # Blueprint path for the humanoid agent to spawn in the UE level
        agent_bp = "/Game/TrafficSystem/Pedestrian/Base_User_Agent.Base_User_Agent_C"

        # Initial spawn position and facing direction for the humanoid (2D)
        spawn_location = Vector(0, 0)
        spawn_forward = Vector(0, 1)
        self.agent = Humanoid(
            communicator=self.communicator,
            position=spawn_location,
            direction=spawn_forward,
            config=self.config,
            map=self.map
        )

        self.action_planner = LocalPlanner(
            agent=self.agent,
            model=self.action_planner_llm,
            rule_based=False)

        # Spawn the humanoid agent in the Unreal world
        # NOTE: name is ignored for humanoid type, but required by the API.
        self.communicator.spawn_agent(self.agent, name=None, model_path=agent_bp, type="humanoid")

        # Cache the generated UE actor name
        self.agent_name = self.communicator.get_humanoid_name(self.agent.id)

        # Define a target position the agent is encouraged to move toward (example value)
        self.target = Vector(1000, 0)

        # Return initial observation
        # observation = self.communicator.get_camera_observation(self.agent.camera_id, "lit")
        observation = self.communicator.unrealcv.get_location(self.agent_name)
        return observation

    def step(self, action):
        """Use action planner to execute the given action."""
        # Parse the action text and map it to the action space
        primitive_actions = self.action_planner.parse(action)
        self.action_planner.execute(primitive_actions)

        # Get current location from UE (x, y, z) and convert to 2D Vector
        loc_3d = self.communicator.unrealcv.get_location(self.agent_name)
        # loc_3d is a numpy array; explicitly use x, y to build our 2D Vector
        location = Vector(loc_3d[0], loc_3d[1])

        # Camera observation for RL
        observation = location

        # Reward: negative Euclidean distance in 2D plane
        reward = -location.distance(self.target)

        return observation, reward

# %% [markdown]
# ## Gym-like Interface

# %%
agent = Agent(goal='Go to (1700, -1700) and pick up GEN_BP_Box_1_C.')
env = Environment(communicator)

obs = env.reset()

# Roll out a short trajectory
for _ in range(100):
    action = agent.action(obs)
    obs, reward = env.step(action)
    print(f"obs: {obs}, reward: {reward}")
    # Plug this into your RL loop / logging as needed
# Out:
# 2026-01-11 23:55:21,016 - SimWorld.BaseLLM - INFO - Initialized LLM client for model -- gpt-4o, url -- default
# 2026-01-11 23:55:21,287 - SimWorld.BaseLLM - INFO - Initialized LLM client for model -- gpt-4o-mini, url -- default
# 2026-01-11 23:55:21,288 - SimWorld.JsonLoader - WARNING - File not found at '../simworld/roads.json', falling back to default location
# (0.0, 0.0, 600)
# 2026-01-11 23:55:31,746 - SimWorld.LocalPlanner - INFO - Agent 0 Response: {"action_queue":[1,2],"destination":{"x":1700,"y":-1700},"object_name":"GEN_BP_Box_1_C","reasoning":"I need to navigate to the target location to pick up the box."}, call time: 1.8021306991577148
# 2026-01-11 23:55:31,747 - SimWorld.LocalPlanner - INFO - Agent 0 Actions: HighLevelActionSpace(destination=Vector(x=1700.0, y=-1700.0), object_name=GEN_BP_Box_1_C, action_queue=[1, 2], reasoning=I need to navigate to the target location to pick up the box.)
# 2026-01-11 23:55:31,747 - SimWorld.LocalPlanner - INFO - Agent 0 Target destination: Vector(x=1700.0, y=-1700.0)
# 2026-01-11 23:55:31,748 - SimWorld.LocalPlanner - INFO - Agent 0 is navigating to Vector(x=1700.0, y=-1700.0), current position: Vector(x=0.0, y=0.0), vision based mode
# 2026-01-11 23:55:36,986 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=The destination is to the left, so I will turn 45 degrees to move toward the left direction, while ensuring I stay on the sidewalk.)
# 2026-01-11 23:55:42,636 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=Moving forward will keep me on the sidewalk towards the destination.)
# 2026-01-11 23:55:53,541 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align more closely with my destination, I need to turn right by 45 degrees after previously turning left. This will help me navigate towards the sidewalk and away from obstacles.)
# 2026-01-11 23:56:00,049 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=In the previous actions, I turned right 45 degrees and then stepped forward. The current situation shows a clear area, but without any specific obstacles or sidewalks visible, it's safer to assess the environment before taking further action.)
# 2026-01-11 23:56:05,477 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=Given the previous actions and the current environment, I will step forward for 5 seconds to continue approaching the destination while staying on the sidewalk.)
# 2026-01-11 23:56:15,738 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=You need to turn right 45 degrees to align better towards your destination.)
# 2026-01-11 23:56:21,805 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align my direction toward the destination without walking directly into potential obstacles.)
# 2026-01-11 23:56:27,857 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=No significant change in environment is observed. It's best to wait and assess the surroundings further before making a decision.)
# 2026-01-11 23:56:33,610 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will take a step forward as I have already turned to face the direction of my destination, and I need to start moving towards it while ensuring that I'm on the sidewalk.)
# 2026-01-11 23:56:43,703 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=No immediate obstacles are detected in the current view, but it's wise to stay cautious and gather more information before proceeding.)
# 2026-01-11 23:56:49,452 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning 45 degrees clockwise will help to align more directly toward the destination while still maintaining awareness of the surroundings.)
# 2026-01-11 23:56:56,177 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to maintain my current direction and make progress toward the destination while keeping an eye on my surroundings.)
# 2026-01-11 23:57:06,984 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the current situation and previous actions, it's best to assess the surroundings further before making any movement.)
# 2026-01-11 23:57:12,167 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to continue moving in the direction I am facing, while remaining on the sidewalk.)
# 2026-01-11 23:57:23,005 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To change my direction towards the destination while ensuring I remain on the sidewalk.)
# 2026-01-11 23:57:29,176 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning right 45 degrees will align my direction closer to the target while checking the surroundings.)
# 2026-01-11 23:57:35,847 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to continue moving towards my destination while ensuring I remain aware of my surroundings.)
# 2026-01-11 23:57:46,262 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to continue moving toward my destination while remaining on the sidewalk.)
# 2026-01-11 23:57:56,430 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=The previous action history shows that I have already turned to the left and moved forward; I will continue moving forward for 5 seconds on the sidewalk.)
# 2026-01-11 23:58:06,483 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning 45 degrees clockwise will help align my direction toward the destination while ensuring a safe path on the sidewalk.)
# 2026-01-11 23:58:12,571 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to continue moving toward my destination while monitoring my surroundings.)
# 2026-01-11 23:58:23,490 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous and current views, I cannot see any immediate obstacles or changes in the environment. It's prudent to assess the surroundings further before taking action.)
# 2026-01-11 23:58:29,554 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to move closer to my destination while remaining cautious of my surroundings.)
# 2026-01-11 23:58:39,626 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning 45 degrees clockwise will help orient towards the destination while maintaining safety.)
# 2026-01-11 23:58:45,665 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous actions and the current view, it’s prudent to assess the surroundings before proceeding. Doing nothing allows for further observation.)
# 2026-01-11 23:58:51,432 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=The environment appears to be consistent across both images, indicating no immediate obstacles. Given the previous actions and the need to assess surroundings, doing nothing allows for further observation.)
# 2026-01-11 23:58:56,456 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous actions and the current environment, it is prudent to assess the surroundings further before proceeding with a movement.)
# 2026-01-11 23:59:01,687 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=To align my direction towards the destination while ensuring I stay on the sidewalk.)
# 2026-01-11 23:59:07,823 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Considering the action history and the surroundings, it seems prudent to wait and assess the environment further before making a move.)
# 2026-01-11 23:59:12,874 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to start moving towards my destination while avoiding obstacles.)
# 2026-01-11 23:59:23,377 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=Turning left 45 degrees will help align towards the destination while ensuring I stay on the sidewalk.)
# 2026-01-11 23:59:29,922 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=Need to turn left to align with the destination direction.)
# 2026-01-11 23:59:36,736 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Based on the previous action history, I have already turned left twice and moved forward. The current view does not provide any specific obstacles or paths to navigate. Since I need to ensure safety and assess my surroundings further, doing nothing is the best choice.)
# 2026-01-11 23:59:42,044 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=To align towards the destination while avoiding potential obstacles.)
# 2026-01-11 23:59:47,971 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=Turning left 45 degrees aligns my direction more closely with the target destination.)
# 2026-01-11 23:59:54,454 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=I need to turn left 45 degrees to align better with my destination.)
# 2026-01-12 00:00:00,467 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=I need to turn left 45 degrees to align my direction towards the destination.)
# 2026-01-12 00:00:06,900 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=90.0, clockwise=True, reasoning=To navigate effectively towards the destination while avoiding obstacles, a right turn of 90 degrees is necessary to align with the path.)
# 2026-01-12 00:00:13,046 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align my direction toward the destination, I will turn 45 degrees clockwise.)
# 2026-01-12 00:00:18,861 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 199889, Requested 2154. Please try again in 612ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:00:18,862 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:00:24,337 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=I need to adjust my direction to align better with the destination, considering the recent turns.)
# 2026-01-12 00:00:30,707 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=90.0, clockwise=True, reasoning=I need to adjust my direction to align more effectively towards my destination, while also ensuring I remain on the sidewalk.)
# 2026-01-12 00:00:36,516 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 199653, Requested 2154. Please try again in 542ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:00:36,517 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:00:42,809 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To navigate towards the destination safely and efficiently, I will turn 45 degrees to the right, aligning my path better with the destination while ensuring that I avoid any potential obstacles.)
# 2026-01-12 00:00:48,775 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align better towards the destination and to account for any obstacles in my path.)
# 2026-01-12 00:00:56,433 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=90.0, clockwise=True, reasoning=To improve my alignment towards the destination while ensuring I stay on the sidewalk.)
# 2026-01-12 00:01:02,274 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2154. Please try again in 646ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:01:02,275 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:01:07,645 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align my direction more optimally towards the destination while ensuring I maintain a safe path.)
# 2026-01-12 00:01:14,273 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=I need to adjust my direction to continue moving towards my destination without hitting obstacles or stepping into the roadway.)
# 2026-01-12 00:01:20,122 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2154. Please try again in 646ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:01:20,123 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:01:25,891 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning right 45 degrees aligns my direction more towards the destination while keeping a safe distance from obstacles.)
# 2026-01-12 00:01:32,563 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning clockwise 45 degrees to align better with the direction towards the destination.)
# 2026-01-12 00:01:38,555 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 197866, Requested 2154. Please try again in 6ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:01:38,556 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:01:43,990 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=I need to adjust my orientation to better align with the destination. Turning clockwise by 45 degrees will help me navigate towards the sidewalk.)
# 2026-01-12 00:01:50,332 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align with the direction towards the destination while considering the action history.)
# 2026-01-12 00:01:58,781 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align properly towards the sidewalk and ensure safe movement towards my destination.)
# 2026-01-12 00:02:04,624 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 198775, Requested 2154. Please try again in 278ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:02:04,625 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:02:10,340 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=The previous actions involved turning right 45 degrees, which aligns with my current position facing forward. I need to check my surroundings before stepping forward.)
# 2026-01-12 00:02:17,136 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=I need to adjust my direction to face the destination properly after my previous turns. Turning 45 degrees clockwise will help me align closer to my path while ensuring I stay on the sidewalk.)
# 2026-01-12 00:02:24,672 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align more closely with the direction of the destination and ensure safe navigation.)
# 2026-01-12 00:02:30,550 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2154. Please try again in 646ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:02:30,550 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:02:36,785 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=I need to adjust my direction to align better with the destination, which is at a relative angle of -45 degrees. Turning 45 degrees clockwise will set my heading towards the correct path.)
# 2026-01-12 00:02:42,979 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To orient myself correctly towards the destination, I need to turn right by 45 degrees.)
# 2026-01-12 00:02:48,752 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 198081, Requested 2154. Please try again in 70ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:02:48,753 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:02:56,121 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=I need to adjust my direction to align better with the destination.)
# 2026-01-12 00:03:03,090 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align better with the path towards the destination while ensuring awareness of the surroundings.)
# 2026-01-12 00:03:09,608 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=I need to adjust my direction to face my destination more accurately, as I previously turned right 45 degrees.)
# 2026-01-12 00:03:17,601 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align my direction towards the destination after the previous turns.)
# 2026-01-12 00:03:23,393 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 199781, Requested 2154. Please try again in 580ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:03:23,394 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:03:29,556 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Based on the action history, I have already turned right 45 degrees and am in a stable position. It would be better to assess the surroundings before taking any steps.)
# 2026-01-12 00:03:35,875 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=It is important to assess the environment further before taking any action, as previous actions have not led to a clear path towards the destination.)
# 2026-01-12 00:03:40,616 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2147. Please try again in 644ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:03:40,617 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:03:46,725 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=Since I have turned right 45 degrees, I will step forward to continue moving towards my destination without any obstacles in the way.)
# 2026-01-12 00:03:57,041 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=45.0, direction=None, angle=45.0, clockwise=False, reasoning=To safely navigate toward the destination while avoiding obstacles, I will turn left by 45 degrees.)
# 2026-01-12 00:04:03,350 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=I need to turn left to align better with my destination.)
# 2026-01-12 00:04:10,710 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=To adjust my direction towards the destination and avoid potential obstacles.)
# 2026-01-12 00:04:16,594 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 198088, Requested 2153. Please try again in 72ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:04:16,594 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:04:21,889 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=I have turned left 45 degrees previously and need to adjust my direction to navigate safely towards the sidewalk while avoiding obstacles.)
# 2026-01-12 00:04:28,175 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=I need to turn 45 degrees to the right to align my path towards the destination.)
# 2026-01-12 00:04:33,914 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 198901, Requested 2153. Please try again in 316ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:04:33,915 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:04:39,142 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=Turning left 45 degrees will align me better to navigate towards the destination while ensuring I stay on the sidewalk.)
# 2026-01-12 00:04:45,529 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=To align myself better towards the destination while avoiding obstacles on the sidewalk.)
# 2026-01-12 00:04:51,353 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 199394, Requested 2153. Please try again in 464ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:04:51,354 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:04:56,916 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=The environment does not appear to change significantly, indicating it may not be safe to step forward. I will wait and assess the situation further.)
# 2026-01-12 00:05:02,936 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will move forward for 5 seconds to begin making progress towards my destination while ensuring I stay on the sidewalk.)
# 2026-01-12 00:05:13,456 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning clockwise by 45 degrees will align me better with the path toward my destination while avoiding potential obstacles.)
# 2026-01-12 00:05:20,425 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to cover distance while ensuring I stay on the sidewalk.)
# 2026-01-12 00:05:31,055 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous and current views, it seems that the environment is consistent and may not have any immediate obstacles. However, I should still ensure I have a clear path before making any further movement.)
# 2026-01-12 00:05:38,291 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the images and my current surroundings, I will assess the area further before taking any action.)
# 2026-01-12 00:05:43,041 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2149. Please try again in 644ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:05:43,042 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:05:48,682 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=Adjusting my direction to face the destination more accurately.)
# 2026-01-12 00:05:55,629 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=The previous actions involved turning left but no further movement has taken place. Given the lack of visible obstacles and the need to carefully assess the surroundings, it is prudent to do nothing at this moment.)
# 2026-01-12 00:06:00,408 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2147. Please try again in 644ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:06:00,409 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:06:06,800 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous actions and the current view, I will choose to do nothing for now to reassess the surroundings.)
# 2026-01-12 00:06:13,663 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=The environment appears unchanged, and no immediate action is necessary.)
# 2026-01-12 00:06:18,516 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2144. Please try again in 643ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:06:18,517 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:06:24,584 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning 45 degrees clockwise to adjust my direction towards the destination while ensuring I stay on the sidewalk.)
# 2026-01-12 00:06:30,905 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous actions and the current view, there is no new information to suggest moving or turning is necessary at this moment.)
# 2026-01-12 00:06:35,630 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2147. Please try again in 644ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:06:35,631 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:06:40,922 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous actions and the current situation without any visible obstacles or changes in the environment, it is prudent to do nothing and reassess the surroundings.)
# 2026-01-12 00:06:45,669 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 198903, Requested 2147. Please try again in 315ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:06:45,670 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:06:51,290 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the recent action history and the lack of obstacles in the current view, I will wait for more information before making a movement decision.)
# 2026-01-12 00:06:56,956 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=Turning 45 degrees clockwise will help orient towards the destination without stepping into potential obstacles.)
# 2026-01-12 00:07:02,731 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2147. Please try again in 644ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:07:02,732 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:07:07,533 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=Turning left 45 degrees aligns me better toward the destination.)
# 2026-01-12 00:07:14,724 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=I have previously turned left and right but have not moved forward yet. The current view does not indicate any immediate obstacles, so I will wait before taking any further action.)
# 2026-01-12 00:07:19,463 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2150. Please try again in 645ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:07:19,464 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:07:25,144 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the images show a flat surface with no apparent obstacles, it may be safe to proceed cautiously. However, since there are no immediate indications of walking paths or surroundings, doing nothing for now might be prudent.)
# 2026-01-12 00:07:29,923 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 197868, Requested 2147. Please try again in 4ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:07:29,924 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:07:34,637 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=No immediate walking actions are necessary as the surroundings appear unchanged.)
# 2026-01-12 00:07:40,519 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align better with the destination, I will turn 45 degrees to the right, which will help in navigating towards it.)
# 2026-01-12 00:07:46,254 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2147. Please try again in 644ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:07:46,255 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:07:52,116 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will take a step forward for 5 seconds to start moving toward my destination while adhering to the requirement to check for surroundings.)
# 2026-01-12 00:08:02,119 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=STEP_FORWARD, duration=5.0, direction=0, angle=None, clockwise=None, reasoning=I will step forward for 5 seconds to continue moving towards my destination while ensuring I am on the sidewalk.)
# 2026-01-12 00:08:12,718 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the current view and the recent history of actions, it would be prudent to assess the surroundings more before making any movement.)
# 2026-01-12 00:08:18,032 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=True, reasoning=To align myself properly towards the destination, I'll turn 45 degrees clockwise since the relative angle to it is -45 degrees.)
# 2026-01-12 00:08:24,698 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous actions and the current views, it seems best to evaluate the surroundings and not take immediate action.)
# 2026-01-12 00:08:29,532 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2147. Please try again in 644ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:08:29,533 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:08:35,117 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Based on the action history, I previously chose to do nothing after turning. Since both views show the same scene, it seems safe to remain stationary for now.)
# 2026-01-12 00:08:39,835 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 198967, Requested 2147. Please try again in 334ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:08:39,836 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:08:45,370 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=No immediate action is necessary based on the current environment.)
# 2026-01-12 00:08:51,835 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=To adjust my direction towards the destination while ensuring I'm aware of my surroundings.)
# 2026-01-12 00:08:57,648 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 198211, Requested 2147. Please try again in 107ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:08:57,649 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# 2026-01-12 00:09:02,367 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=TURN_AROUND, duration=None, direction=None, angle=45.0, clockwise=False, reasoning=To align better towards the destination while avoiding obstacles.)
# 2026-01-12 00:09:08,489 - SimWorld.LocalPlanner - INFO - Agent 0 is taking action LowLevelActionSpace(choice=DO_NOTHING, duration=None, direction=None, angle=None, clockwise=None, reasoning=Given the previous actions and the images, it seems like I should take a moment to assess the environment before proceeding.)
# 2026-01-12 00:09:13,317 - SimWorld.A2ALLM - ERROR - Error in generate_instructions_openai: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-qKLPRS1rera3JgMKvUNTZlyo on tokens per min (TPM): Limit 200000, Used 200000, Requested 2150. Please try again in 645ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2026-01-12 00:09:13,317 - SimWorld.LocalPlanner - ERROR - Parse failed, response is None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       7 for _ in range(100):
#       8     action = agent.action(obs)
# ----> 9     obs, reward = env.step(action)
#      10     print(f"obs: {obs}, reward: {reward}")
#      11     # Plug this into your RL loop / logging as needed
#
# Cell In[5], line 55, in Environment.step(self, action)
#      53 # Parse the action text and map it to the action space
#      54 primitive_actions = self.action_planner.parse(action)
# ---> 55 self.action_planner.execute(primitive_actions)
#      57 # Get current location from UE (x, y, z) and convert to 2D Vector
#      58 loc_3d = self.communicator.unrealcv.get_location(self.agent_name)
#
# File ~/Desktop/workspace/simworld/SimWorld/simworld/local_planner/local_planner.py:104, in LocalPlanner.execute(self, actions)
#     102 for action in action_queue:
#     103     if action == HighLevelAction.NAVIGATE.value:
# --> 104         self.navigate_to(destination)
#     105     elif action == HighLevelAction.PICK_UP.value:
#     106         self.pick_up(object_name)
#
# File ~/Desktop/workspace/simworld/SimWorld/simworld/local_planner/local_planner.py:120, in LocalPlanner.navigate_to(self, destination)
#     118         self.navigate_rule_based(point)
#     119 else:
# --> 120     self.navigate_vision_based(destination)
#
# File ~/Desktop/workspace/simworld/SimWorld/simworld/local_planner/local_planner.py:202, in LocalPlanner.navigate_vision_based(self, point)
#     191 action_str = f'I was at {self.agent.position} and I want to go to {point}. The relative distance is {relative_distance} cm and the relative angle is {angle} degrees. After I made the decision, '
#     193 user_prompt = NAVIGATION_USER_PROMPT.format(
#     194     current_position=self.agent.position,
#     195     current_direction=self.agent.direction,
#    (...)
#     199     action_history=self.action_history
#     200 )
# --> 202 response, _ = self.model.generate_instructions(
#     203     system_prompt=NAVIGATION_SYSTEM_PROMPT,
#     204     user_prompt=user_prompt,
#     205     images=images,
#     206     response_format=LowLevelActionSpace,
#     207 )
#     209 if response is None:
#     210     self.logger.error('Parse failed, response is None')
#
# File ~/Desktop/workspace/simworld/SimWorld/simworld/llm/retry.py:53, in retry_api_call.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      51 for attempt in range(max_retries + 1):
#      52     if rate_limit_per_min is not None:
# ---> 53         time.sleep(60 / rate_limit_per_min)
#      54     try:
#      55         return func(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
communicator.disconnect()
