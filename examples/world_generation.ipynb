# %%
### World Generation in Unreal Engine
# This script is used to generate the world in Unreal Engine. 
# Make sure you have already generated the city layout.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from simworld.config import Config
from simworld.communicator.communicator import Communicator
from simworld.communicator.unrealcv import UnrealCV

# %%
config = Config()

# %%
# Start the game in Unreal Engine first before running the following code.

# %%
communicator = Communicator(UnrealCV())
# Out:
# INFO:__init__:230:Got connection confirm: b'connected to gym_citynav'
# =>Info: using ip-port socket

# %%
communicator.generate_world('<path to your progen_world.json>', config['citygen.ue_asset_path'], run_time=False)
# Out:
# 2026-01-11 23:17:15,347 - SimWorld.JsonLoader - WARNING - File not found at '<path to your progen_world.json>', falling back to default location
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/workspace/simworld/SimWorld/simworld/utils/load_json.py:34, in load_json(file_path)
#      33 try:
# ---> 34     with open(file_path, 'r') as f:
#      35         return json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '<path to your progen_world.json>'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/workspace/simworld/SimWorld/simworld/utils/load_json.py:42, in load_json(file_path)
#      41     logger.warning(f"File not found at '{file_path}', falling back to default location")
# ---> 42     return load_default_json(file_name)
#      43 except Exception as e:
#
# File ~/Desktop/workspace/simworld/SimWorld/simworld/utils/load_json.py:20, in load_default_json(file_name, default_package)
#      11 """Load a JSON file from the default location.
#      12
#      13 Args:
#    (...)
#      18     The JSON data from the file.
#      19 """
# ---> 20 with pkg_resources.files(default_package).joinpath(file_name).open('r') as f:
#      21     return json.load(f)
#
# File ~/miniforge3/envs/simworld/lib/python3.10/pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1118     encoding = io.text_encoding(encoding)
# -> 1119 return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                            newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ubuntu/Desktop/workspace/simworld/SimWorld/simworld/data/<path to your progen_world.json>'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 communicator.generate_world('<path to your progen_world.json>', config['citygen.ue_asset_path'], run_time=False)
#
# File ~/Desktop/workspace/simworld/SimWorld/simworld/communicator/communicator.py:825, in Communicator.generate_world(self, world_json, ue_asset_path, run_time)
#     823 generated_ids = set()
#     824 # Load world from JSON
# --> 825 world_setting = load_json(world_json)
#     826 # Use pandas data structure, convert JSON data to pandas dataframe
#     827 nodes = world_setting['nodes']
#
# File ~/Desktop/workspace/simworld/SimWorld/simworld/utils/load_json.py:44, in load_json(file_path)
#      42     return load_default_json(file_name)
#      43 except Exception as e:
# ---> 44     raise FileNotFoundError(f"Could not load JSON file from '{file_path}' or default location") from e
#
# FileNotFoundError: Could not load JSON file from '<path to your progen_world.json>' or default location

# %%
communicator.clear_env(keep_roads=False)

# %%
# Leave the game in Unreal Engine first before disconnecting the connection.
# Otherwise, the game will crash.

# %%
communicator.disconnect()
