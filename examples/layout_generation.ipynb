# %%
### City Generation
# This script is used to generate the city layout. `generate_city()` is the main function to randomly generate the city layout.
# `export_city()` is the function to export the city layout to the `output` folder.
# Please refer to the documentation for more functions to use.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from simworld.citygen.function_call.city_function_call import CityFunctionCall
from simworld.config import Config

# %%
config = Config()

# %%
cfc = CityFunctionCall(config, num_segments=20)
cfc.generate_city()
cfc.export_city('E:\Projects\SimWorld\output_20')

# %%
# cfc = CityFunctionCall(config)

# cfc.add_road([0, 0], [200, 0])
# # cfc.add_road([200, 0], [200, -200])
# cfc.add_road([0, 0], [-200, 0])
# # cfc.add_road([-200, 0], [-200, -200])
# cfc.add_road([0, 0], [0, -200])
# # cfc.add_road([-200, -200], [0, -200])
# # cfc.add_road([0, -200], [200, -200])
# cfc.add_road([0, 0], [0, 200])

# cfc.generate_building_alone_roads()
# # cfc.generate_element_around_buildings()
# cfc.generate_element_alone_roads()
# cfc.export_city('D:\Projects\SimWorld\output_test')

# %%
# cfc = CityFunctionCall(config)
# block_size = 200

# # 2x2 grid with 12 roads total
# # Each block has 3 roads: 2 vertical + 1 horizontal
# # Total: 4 blocks × 3 roads = 12 roads

# # Block 1 (top-left): [-200, 200] to [0, 0]
# cfc.add_road([-200, 200], [-200, 0])    # Left vertical
# cfc.add_road([-200, 0], [0, 0])         # Bottom horizontal
# cfc.add_road([0, 200], [0, 0])          # Right vertical

# # Block 2 (top-right): [0, 200] to [200, 0]
# cfc.add_road([0, 200], [0, 0])          # Left vertical (shared with block 1)
# cfc.add_road([0, 0], [200, 0])          # Bottom horizontal
# cfc.add_road([200, 200], [200, 0])      # Right vertical

# # Block 3 (bottom-left): [-200, 0] to [0, -200]
# cfc.add_road([-200, 0], [-200, -200])   # Left vertical
# cfc.add_road([-200, -200], [0, -200])   # Top horizontal
# cfc.add_road([0, 0], [0, -200])         # Right vertical (shared with block 4)

# # Block 4 (bottom-right): [0, 0] to [200, -200]
# cfc.add_road([0, 0], [0, -200])         # Left vertical (shared with block 3)
# cfc.add_road([0, -200], [200, -200])    # Top horizontal
# cfc.add_road([200, 0], [200, -200])     # Right vertical

# cfc.generate_building_alone_roads()
# cfc.generate_element_around_buildings()
# cfc.generate_element_alone_roads()
# cfc.export_city('D:\\Projects\\SimWorld\\output_test')

# %%
# i = 0
# road_num = 15
# while i < 5:
#     cfc = CityFunctionCall(config, seed=i, num_segments=road_num)
#     cfc.generate_road_network()
#     cfc.generate_building_alone_roads()
#     cfc.generate_element_alone_roads()
#     cfc.export_city(f'../output_test/road_{road_num}/map_{i}')
#     i += 1

# %%
# cfc = CityFunctionCall(config)
# cfc.visualization('D:/Projects/SimWorld/output_test/road_15/map_0')
